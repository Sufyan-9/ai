# %%
#fruits= ('appple','banana','cherry','mango','peach')
#print('last element:',fruits[-1])
#fruits_list= list (fruits)
#fruits_list[2]= 'orange'
#print('modified list:',fruits_list)
#set_a= {1,2,3,4,5,6}
#set_b= {5,6,7,8,9}
#print('union :',set_a | set_b)
#print('intersection:',set_a& set_b)
#print('difference:',set_a -set_b)
#print('difference:',set_b-set_a)
students= {'ali':85,'nouman':65, 'sufyan':99,'rehan':30}
print('keys:',students.keys())
print('value:', students.values())
students['ali']=95
print('update dictionary:',students)
del students['sufyan']
print('after deletion:',students)
# Out:
# keys: dict_keys(['ali', 'nouman', 'sufyan', 'rehan'])
# value: dict_values([85, 65, 99, 30])
# update dictionary: {'ali': 95, 'nouman': 65, 'sufyan': 99, 'rehan': 30}
# after deletion: {'ali': 95, 'nouman': 65, 'rehan': 30}
